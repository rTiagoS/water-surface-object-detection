# %% [markdown]
# ## Version 005
#
# ### Changes
# - Using transfer learning model obtained from WSODD dataset
# - Get a new model trained from the TCC dataset

# %%
# !pip install albumentations

# %%
# !pip install wandb

# %%
# %cd ../app
# Out:
# /usr/src/app

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.2-43-gdb2ee5f Python-3.8.13 torch-1.13.0a0+08820cb CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 3910MiB)
# Setup complete ✅ (20 CPUs, 31.1 GB RAM, 131.1/164.0 GB disk)

# %%
import cv2 # Computacional Vision manipulations on Images from Taco Dataset
import albumentations as A # To pre processing images and also bounding boxes parameters
import wandb
import numpy as np # To perform numeric operations on Digital Image Processing
import pandas as pd # To manipulate dataframes
import matplotlib.pyplot as plt # To visualize images
import seaborn as sns
import random # To visualize and image

# %% [markdown]
# # Custom Training with YOLOv5-based model

# %%
# !ls /usr/src/dataset/tcc_dataset_v005
# Out:
# README.roboflow.txt  data.yaml	train  valid

# %%
data_path = '/usr/src/dataset/tcc_dataset_v005'

# %%
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#  ········
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python train.py --img 416 --batch 16 --epochs 300 --data /usr/src/dataset/tcc_dataset_v005/data.yaml --weights /usr/src/results/002/weights/best.pt --cache
# Out:
# wandb: Currently logged in as: rtiagosa. Use `wandb login --relogin` to force relogin
# train: weights=/usr/src/results/002/weights/best.pt, cfg=, data=/usr/src/dataset/tcc_dataset_v005/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=16, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# remote: Enumerating objects: 679, done.
# remote: Counting objects: 100% (398/398), done.
# remote: Compressing objects: 100% (80/80), done.
# remote: Total 679 (delta 348), reused 355 (delta 318), pack-reused 281
# ...
